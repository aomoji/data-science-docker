# %%
from pathlib import Path
import pandas as pd
import feather
import time
import missingno as msno
import japanize_matplotlib
import watermark
from pprint import pprint

# %load_ext watermark
# Out:
# /Users/anosillus/.local/share/virtualenvs/沖縄セルラー-xTe5YlCv/lib/python3.7/site-packages/japanize_matplotlib/__init__.py:13: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.
#   font_list = font_manager.createFontList(font_files)

# %%
# %watermark
# Out:
# 2019-11-11T17:38:02+09:00
#
# CPython 3.7.5
# IPython 7.9.0
#
# compiler   : Clang 11.0.0 (clang-1100.0.33.8)
# system     : Darwin
# release    : 18.7.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit

# %%
process_path = './../data/processed'
pickled_row = process_path + '/pickled_row/'

# %%
# %%time
# 面倒なので読み込みは関数化していない。
# 読み込みの高速化を確認出来る。
site_log_df = pd.read_feather(pickled_row + 'site_log_df.feather')
order_df = pd.read_pickle(pickled_row + 'order_df.pickle')
wifi_df = pd.read_feather(pickled_row + 'wifi_df.feather')
# Out:
# CPU times: user 146 ms, sys: 81.6 ms, total: 227 ms
# Wall time: 411 ms

# %%
msno.matrix(site_log_df)
print(site_log_df.Extra.unique())
# Out:
# [nan]

# %%
site_log_df.drop('Extra', axis=1, inplace=True)

# %%
msno.matrix(order_df)

# %%
msno.bar(order_df)

# %%
msno.matrix(wifi_df)
print(wifi_df['施設の写真'].unique())

# %%
wifi_df.drop(['施設の写真'], axis=1, inplace=True)

# %%
msno.matrix(wifi_df)
